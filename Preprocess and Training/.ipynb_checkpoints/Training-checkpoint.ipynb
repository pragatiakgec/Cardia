# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
import sklearn.metrics as metrics

# %%
data  = pd.read_csv("../Data/heart_disease_training_data.csv")

# %%
#Target Attributes 

feat = ['PhysicalHealth', 'AgeCategory', 'Diabetic', 'Stroke', 'DiffWalking', 'KidneyDisease', 'MentalHealth', 'SkinCancer','Smoking', 'BMI']
features = data[feat]
target = data['HeartDisease']

# %%
#training and testing data split
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=1)

# %%
#Decision Tree
from sklearn.tree import DecisionTreeClassifier 
import sklearn.metrics as metrics
import matplotlib.pyplot as plt

#Building decision tree model
clf = DecisionTreeClassifier()
clf = clf.fit(X_train,y_train)
#Predict the response for test dataset
y_pred = clf.predict(X_test)

#Perormance evaluation of Decision tree
print("Confusion Matrix", metrics.confusion_matrix(y_test, y_pred))
print("Accuracy of the model is", metrics.accuracy_score(y_test, y_pred))
print("precision of the model is", metrics.precision_score(y_test, y_pred))
print("Recall of the model is", metrics.recall_score(y_test, y_pred))
print("ROC Curve")
tpr, fpr, thres=metrics.roc_curve(y_test, y_pred)

plt.plot(tpr, fpr)
plt.title("ROC curve")
plt.xlabel("True Positive Rate")
plt.ylabel("False Positive Rate")
plt.show()
# Out:
# Confusion Matrix [[77042  5327]
#  [ 6523  1624]]
# Accuracy of the model is 0.869083918865173
# precision of the model is 0.23363544813695872
# Recall of the model is 0.19933717932981465
# ROC Curve

# %%
#Building logistic tree model
lr = LogisticRegression(max_iter=150)
lr = lr.fit(X_train,y_train)
#Predict the response for test dataset
y_pred = lr.predict(X_test)

#Perormance evaluation of Decision tree
print("Confusion Matrix", metrics.confusion_matrix(y_test, y_pred))
print("Accuracy of the model is", metrics.accuracy_score(y_test, y_pred))
print("precision of the model is", metrics.precision_score(y_test, y_pred))
print("Recall of the model is", metrics.recall_score(y_test, y_pred))
print("ROC Curve")
tpr, fpr, thres=metrics.roc_curve(y_test, y_pred)

plt.plot(tpr, fpr)
plt.title("ROC curve")
plt.xlabel("True Positive Rate")
plt.ylabel("False Positive Rate")
plt.show()
# Out:
# Confusion Matrix [[81752   617]
#  [ 7548   599]]
# Accuracy of the model is 0.9097949533784082
# precision of the model is 0.4925986842105263
# Recall of the model is 0.07352399656315207
# ROC Curve

# %%
from sklearn.ensemble import RandomForestClassifier

#Building random forest tree model
rf = RandomForestClassifier(n_estimators = 100)
rf = rf.fit(X_train,y_train)
#Predict the response for test dataset
y_pred = rf.predict(X_test)

#Perormance evaluation of Random forest
print("Confusion Matrix", metrics.confusion_matrix(y_test, y_pred))
print("Accuracy of the model is", metrics.accuracy_score(y_test, y_pred))
print("precision of the model is", metrics.precision_score(y_test, y_pred))
print("Recall of the model is", metrics.recall_score(y_test, y_pred))
print("ROC Curve")
tpr, fpr, thres=metrics.roc_curve(y_test, y_pred)

plt.plot(tpr, fpr)
plt.title("ROC curve")
plt.xlabel("True Positive Rate")
plt.ylabel("False Positive Rate")
plt.show()
# Out:
# Confusion Matrix [[79091  3278]
#  [ 6953  1194]]
# Accuracy of the model is 0.8869702594016527
# precision of the model is 0.26699463327370304
# Recall of the model is 0.1465570148520928
# ROC Curve

# %%
#KNN
from sklearn.neighbors import KNeighborsClassifier 

knn = KNeighborsClassifier(n_neighbors=7) 
knn.fit(X_train, y_train)
y_pred_knn=knn.predict(X_test)

print("Confusion Matrix", metrics.confusion_matrix(y_test, y_pred_knn))
print("Accuracy of the model is", metrics.accuracy_score(y_test, y_pred_knn))
print("precision of the model is", metrics.precision_score(y_test, y_pred_knn))
print("Recall of the model is", metrics.recall_score(y_test, y_pred_knn))
print("ROC Curve")
tpr, fpr, thres=metrics.roc_curve(y_test, y_pred_knn)

plt.plot(tpr, fpr)
plt.title("ROC curve")
plt.xlabel("True Positive Rate")
plt.ylabel("False Positive Rate")
plt.show()
# Out:
# Confusion Matrix [[81435   934]
#  [ 7663   484]]
# Accuracy of the model is 0.905022316496531
# precision of the model is 0.34132581100141046
# Recall of the model is 0.0594083711795753
# ROC Curve

# %%
#Gradient Boosting
from sklearn.ensemble import GradientBoostingClassifier
print("Gradient Boosting Classifier")

gb = GradientBoostingClassifier(learning_rate=0.1)
gb.fit(X_train, y_train)
y_pred_gb=gb.predict(X_test)

print("Confusion Matrix", metrics.confusion_matrix(y_test, y_pred_gb))
print("Accuracy of the model is", metrics.accuracy_score(y_test, y_pred_gb))
print("precision of the model is", metrics.precision_score(y_test, y_pred_gb))
print("Recall of the model is", metrics.recall_score(y_test, y_pred_gb))
print("ROC Curve")
tpr, fpr, thres=metrics.roc_curve(y_test, y_pred_gb)

plt.plot(tpr, fpr)
plt.title("ROC curve")
plt.xlabel("True Positive Rate")
plt.ylabel("False Positive Rate")
plt.show()
# Out:
# Gradient Boosting Classifier
# Confusion Matrix [[81921   448]
#  [ 7686   461]]
# Accuracy of the model is 0.9101374342657652
# precision of the model is 0.5071507150715071
# Recall of the model is 0.05658524610285995
# ROC Curve

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

data  = pd.read_csv("../Data/heart_disease_training_data.csv")

# Assuming 'features' and 'target' are already defined
feat = ['PhysicalHealth', 'AgeCategory', 'Diabetic', 'Stroke', 'DiffWalking', 'KidneyDisease', 'MentalHealth', 'SkinCancer','Smoking', 'BMI']
features = data[feat]
target = data['HeartDisease']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=1)

# Standardize the features (optional, but often recommended for neural networks)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Build the model
model = Sequential()
model.add(Dense(units=64, activation='relu', input_dim=X_train_scaled.shape[1]))
model.add(Dense(units=32, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train_scaled, y_train, epochs=100, batch_size=32, validation_data=(X_test_scaled, y_test))

# Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test_scaled, y_test)
print(f'Test Loss: {loss}, Test Accuracy: {accuracy}')

# Save the model to a file
model.save('trained_heart_disease_model.h5')
# Out:
# Epoch 1/100
# 6601/6601 [==============================] - 14s 2ms/step - loss: 0.2502 - accuracy: 0.9101 - val_loss: 0.2482 - val_accuracy: 0.9100
# Epoch 2/100
# 6601/6601 [==============================] - 14s 2ms/step - loss: 0.2473 - accuracy: 0.9105 - val_loss: 0.2482 - val_accuracy: 0.9096
# Epoch 3/100
# 6601/6601 [==============================] - 12s 2ms/step - loss: 0.2469 - accuracy: 0.9105 - val_loss: 0.2476 - val_accuracy: 0.9100
# Epoch 4/100
# 6601/6601 [==============================] - 12s 2ms/step - loss: 0.2467 - accuracy: 0.9105 - val_loss: 0.2467 - val_accuracy: 0.9101
# Epoch 5/100
# 6601/6601 [==============================] - 14s 2ms/step - loss: 0.2464 - accuracy: 0.9107 - val_loss: 0.2483 - val_accuracy: 0.9091
# Epoch 6/100
# 6601/6601 [==============================] - 14s 2ms/step - loss: 0.2462 - accuracy: 0.9108 - val_loss: 0.2475 - val_accuracy: 0.9098
# Epoch 7/100
# 6601/6601 [==============================] - 14s 2ms/step - loss: 0.2461 - accuracy: 0.9107 - val_loss: 0.2470 - val_accuracy: 0.9098
# Epoch 8/100
# 6601/6601 [==============================] - 14s 2ms/step - loss: 0.2461 - accuracy: 0.9107 - val_loss: 0.2469 - val_accuracy: 0.9100
# Epoch 9/100
# 6601/6601 [==============================] - 13s 2ms/step - loss: 0.2459 - accuracy: 0.9109 - val_loss: 0.2469 - val_accuracy: 0.9102
# Epoch 10/100
# 6601/6601 [==============================] - 14s 2ms/step - loss: 0.2459 - accuracy: 0.9108 - val_loss: 0.2469 - val_accuracy: 0.9099
# Epoch 11/100
# 6601/6601 [==============================] - 14s 2ms/step - loss: 0.2457 - accuracy: 0.9109 - val_loss: 0.2466 - val_accuracy: 0.9099
# Epoch 12/100
# 6601/6601 [==============================] - 13s 2ms/step - loss: 0.2456 - accuracy: 0.9109 - val_loss: 0.2472 - val_accuracy: 0.9101
# Epoch 13/100
# 6601/6601 [==============================] - 14s 2ms/step - loss: 0.2456 - accuracy: 0.9111 - val_loss: 0.2468 - val_accuracy: 0.9102
# Epoch 14/100
# 6601/6601 [==============================] - 14s 2ms/step - loss: 0.2454 - accuracy: 0.9109 - val_loss: 0.2470 - val_accuracy: 0.9103
# Epoch 15/100
# 6601/6601 [==============================] - 15s 2ms/step - loss: 0.2455 - accuracy: 0.9110 - val_loss: 0.2469 - val_accuracy: 0.9104
# Epoch 16/100
# 6601/6601 [==============================] - 13s 2ms/step - loss: 0.2453 - accuracy: 0.9108 - val_loss: 0.2472 - val_accuracy: 0.9102
# Epoch 17/100
# 6601/6601 [==============================] - 14s 2ms/step - loss: 0.2453 - accuracy: 0.9109 - val_loss: 0.2470 - val_accuracy: 0.9103
# Epoch 18/100
# 6601/6601 [==============================] - 13s 2ms/step - loss: 0.2452 - accuracy: 0.9110 - val_loss: 0.2468 - val_accuracy: 0.9102
# Epoch 19/100
# 6601/6601 [==============================] - 13s 2ms/step - loss: 0.2453 - accuracy: 0.9111 - val_loss: 0.2469 - val_accuracy: 0.9101
# Epoch 20/100
# 6601/6601 [==============================] - 13s 2ms/step - loss: 0.2450 - accuracy: 0.9111 - val_loss: 0.2471 - val_accuracy: 0.9102
# Epoch 21/100
# 6601/6601 [==============================] - 14s 2ms/step - loss: 0.2450 - accuracy: 0.9110 - val_loss: 0.2467 - val_accuracy: 0.9099
# Epoch 22/100
# 6601/6601 [==============================] - 14s 2ms/step - loss: 0.2450 - accuracy: 0.9110 - val_loss: 0.2466 - val_accuracy: 0.9102
# Epoch 23/100
# 6601/6601 [==============================] - 13s 2ms/step - loss: 0.2450 - accuracy: 0.9112 - val_loss: 0.2470 - val_accuracy: 0.9100
# Epoch 24/100
# 6601/6601 [==============================] - 14s 2ms/step - loss: 0.2450 - accuracy: 0.9113 - val_loss: 0.2468 - val_accuracy: 0.9104
# Epoch 25/100
# 6601/6601 [==============================] - 15s 2ms/step - loss: 0.2449 - accuracy: 0.9113 - val_loss: 0.2473 - val_accuracy: 0.9098
# Epoch 26/100
# 6601/6601 [==============================] - 14s 2ms/step - loss: 0.2448 - accuracy: 0.9113 - val_loss: 0.2472 - val_accuracy: 0.9100
# Epoch 27/100
# 6601/6601 [==============================] - 13s 2ms/step - loss: 0.2448 - accuracy: 0.9112 - val_loss: 0.2471 - val_accuracy: 0.9099
# Epoch 28/100
# 6601/6601 [==============================] - 13s 2ms/step - loss: 0.2448 - accuracy: 0.9113 - val_loss: 0.2477 - val_accuracy: 0.9101
# Epoch 29/100
# 6601/6601 [==============================] - 13s 2ms/step - loss: 0.2448 - accuracy: 0.9112 - val_loss: 0.2470 - val_accuracy: 0.9101
# Epoch 30/100
# 6601/6601 [==============================] - 13s 2ms/step - loss: 0.2445 - accuracy: 0.9113 - val_loss: 0.2471 - val_accuracy: 0.9102
# Epoch 31/100
# 6601/6601 [==============================] - 14s 2ms/step - loss: 0.2446 - accuracy: 0.9113 - val_loss: 0.2471 - val_accuracy: 0.9100
# Epoch 32/100
# 6601/6601 [==============================] - 14s 2ms/step - loss: 0.2446 - accuracy: 0.9111 - val_loss: 0.2469 - val_accuracy: 0.9099
# Epoch 33/100
# 6601/6601 [==============================] - 14s 2ms/step - loss: 0.2444 - accuracy: 0.9113 - val_loss: 0.2474 - val_accuracy: 0.9100
# Epoch 34/100
# 6601/6601 [==============================] - 14s 2ms/step - loss: 0.2446 - accuracy: 0.9113 - val_loss: 0.2470 - val_accuracy: 0.9099
# Epoch 35/100
# 6601/6601 [==============================] - 14s 2ms/step - loss: 0.2444 - accuracy: 0.9114 - val_loss: 0.2469 - val_accuracy: 0.9099
# Epoch 36/100
# 6601/6601 [==============================] - 14s 2ms/step - loss: 0.2444 - accuracy: 0.9113 - val_loss: 0.2475 - val_accuracy: 0.9097
# Epoch 37/100
# 6601/6601 [==============================] - 14s 2ms/step - loss: 0.2443 - accuracy: 0.9115 - val_loss: 0.2471 - val_accuracy: 0.9099
# Epoch 38/100
# 6601/6601 [==============================] - 14s 2ms/step - loss: 0.
100
# 6601/6601 [==============================] - 14s 2ms/step - loss: 0.2431 - accuracy: 0.9120 - val_loss: 0.2490 - val_accuracy: 0.9090
# Epoch 72/100
# 6601/6601 [==============================] - 13s 2ms/step - loss: 0.2431 - accuracy: 0.9119 - val_loss: 0.2483 - val_accuracy: 0.9096
# Epoch 73/100
# 6601/6601 [==============================] - 13s 2ms/step - loss: 0.2431 - accuracy: 0.9121 - val_loss: 0.2486 - val_accuracy: 0.9095
# Epoch 74/100
# 6601/6601 [==============================] - 13s 2ms/step - loss: 0.2431 - accuracy: 0.9121 - val_loss: 0.2482 - val_accuracy: 0.9096
# Epoch 75/100
# 6601/6601 [==============================] - 13s 2ms/step - loss: 0.2431 - accuracy: 0.9121 - val_loss: 0.2494 - val_accuracy: 0.9091
# Epoch 76/100
# 6601/6601 [==============================] - 13s 2ms/step - loss: 0.2431 - accuracy: 0.9119 - val_loss: 0.2489 - val_accuracy: 0.9091
# Epoch 77/100
# 6601/6601 [==============================] - 13s 2ms/step - loss: 0.2431 - accuracy: 0.9122 - val_loss: 0.2486 - val_accuracy: 0.9095
# Epoch 78/100
# 6601/6601 [==============================] - 13s 2ms/step - loss: 0.2430 - accuracy: 0.9120 - val_loss: 0.2486 - val_accuracy: 0.9096
# Epoch 79/100
# 6601/6601 [==============================] - 13s 2ms/step - loss: 0.2430 - accuracy: 0.9123 - val_loss: 0.2491 - val_accuracy: 0.9090
# Epoch 80/100
# 6601/6601 [==============================] - 13s 2ms/step - loss: 0.2430 - accuracy: 0.9121 - val_loss: 0.2488 - val_accuracy: 0.9095
# Epoch 81/100
# 6601/6601 [==============================] - 13s 2ms/step - loss: 0.2429 - accuracy: 0.9122 - val_loss: 0.2500 - val_accuracy: 0.9091
# Epoch 82/100
# 6601/6601 [==============================] - 12s 2ms/step - loss: 0.2430 - accuracy: 0.9120 - val_loss: 0.2489 - val_accuracy: 0.9096
# Epoch 83/100
# 6601/6601 [==============================] - 13s 2ms/step - loss: 0.2429 - accuracy: 0.9121 - val_loss: 0.2493 - val_accuracy: 0.9095
# Epoch 84/100
# 6601/6601 [==============================] - 13s 2ms/step - loss: 0.2428 - accuracy: 0.9121 - val_loss: 0.2490 - val_accuracy: 0.9093
# Epoch 85/100
# 6601/6601 [==============================] - 13s 2ms/step - loss: 0.2429 - accuracy: 0.9120 - val_loss: 0.2501 - val_accuracy: 0.9092
# Epoch 86/100
# 6601/6601 [==============================] - 12s 2ms/step - loss: 0.2427 - accuracy: 0.9123 - val_loss: 0.2489 - val_accuracy: 0.9099
# Epoch 87/100
# 6601/6601 [==============================] - 12s 2ms/step - loss: 0.2429 - accuracy: 0.9119 - val_loss: 0.2488 - val_accuracy: 0.9095
# Epoch 88/100
# 6601/6601 [==============================] - 12s 2ms/step - loss: 0.2427 - accuracy: 0.9120 - val_loss: 0.2495 - val_accuracy: 0.9095
# Epoch 89/100
# 6601/6601 [==============================] - 12s 2ms/step - loss: 0.2428 - accuracy: 0.9123 - val_loss: 0.2492 - val_accuracy: 0.9098
# Epoch 90/100
# 6601/6601 [==============================] - 13s 2ms/step - loss: 0.2428 - accuracy: 0.9123 - val_loss: 0.2489 - val_accuracy: 0.9092
# Epoch 91/100
# 6601/6601 [==============================] - 14s 2ms/step - loss: 0.2427 - accuracy: 0.9121 - val_loss: 0.2493 - val_accuracy: 0.9093
# Epoch 92/100
# 6601/6601 [==============================] - 13s 2ms/step - loss: 0.2427 - accuracy: 0.9123 - val_loss: 0.2493 - val_accuracy: 0.9094
# Epoch 93/100
# 6601/6601 [==============================] - 14s 2ms/step - loss: 0.2426 - accuracy: 0.9123 - val_loss: 0.2491 - val_accuracy: 0.9093
# Epoch 94/100
# 6601/6601 [==============================] - 14s 2ms/step - loss: 0.2427 - accuracy: 0.9122 - val_loss: 0.2496 - val_accuracy: 0.9093
# Epoch 95/100
# 6601/6601 [==============================] - 14s 2ms/step - loss: 0.2427 - accuracy: 0.9122 - val_loss: 0.2489 - val_accuracy: 0.9097
# Epoch 96/100
# 6601/6601 [==============================] - 13s 2ms/step - loss: 0.2427 - accuracy: 0.9123 - val_loss: 0.2496 - val_accuracy: 0.9091
# Epoch 97/100
# 6601/6601 [==============================] - 14s 2ms/step - loss: 0.2426 - accuracy: 0.9122 - val_loss: 0.2494 - val_accuracy: 0.9092
# Epoch 98/100
# 6601/6601 [==============================] - 14s 2ms/step - loss: 0.2427 - accuracy: 0.9124 - val_loss: 0.2499 - val_accuracy: 0.9090
# Epoch 99/100
# 6601/6601 [==============================] - 13s 2ms/step - loss: 0.2426 - accuracy: 0.9121 - val_loss: 0.2494 - val_accuracy: 0.9093
# Epoch 100/100
# 6601/6601 [==============================] - 14s 2ms/step - loss: 0.2427 - accuracy: 0.9123 - val_loss: 0.2491 - val_accuracy: 0.9095
# 2829/2829 [==============================] - 4s 1ms/step - loss: 0.2491 - accuracy: 0.9095
# Test Loss: 0.24908268451690674, Test Accuracy: 0.9095187783241272
# C:\Users\ADMIN\anaconda3\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import pickle

#dump on picle
pickle.dump(gb, open('../Model/GB_heartdiseasemodel.pkl','wb'))
